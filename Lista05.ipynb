# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel1104-King/ADS025/blob/master/Lista05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplin:Probabilidade e estátisticas
#Aluno:Gabriel caldeira
#Matricula:20114290082
#Lista_05

#Questãp_01
#A)
'''import statistics
Consumo  = [10,13,17,9,8,11,13,7]
Sal = statistics.mean(Consumo)
print ('Á média simples é: ',Sal)
#B)
import statistics
Consumo =[10,13,17,9,8,11,13,7]
Sal = statistics.harmonic_mean(Consumo)
print('Á média harmonica:',Sal)
#C)
from scipy.stats.mstats import gmean
ConsumoSal = gmean([10,13,17,9,8,11,13,7])
print('Á média geométrica é:',ConsumoSal)
#D)
import statistics
Consumo = [10,13,17,9,8,11,13,7]
Sal = statistics.mode(Consumo)
print('Á média moda é:',Sal)
#E)
import statistics
Consumo = [10,13,17,9,8,11,13,17]
Sal = statistics.variance(Consumo)
print('Á variância é:',Sal)
#F)
import statistics
Comsumo =[10,13,17,9,8,11,13,17]
Sal = statistics.stdev(Consumo)
print('O desvio padrão é:',Sal)'''

#Questão_02
'''#A)
import statistics
Escala=[67,73,63,72,77,78,81,77,80]
Ansiedade1=statistics.mean(Escala)
print('Á média simples é:',Ansiedade1)
Ansiedade2 = statistics.harmonic_mean(Escala)
print('Á média harmonica é:',Ansiedade2)
from scipy.stats.mstats import gmean
EscalaG = gmean([67,73,63,72,77,78,81,77,80])
print ('Á média geométrica é:',EscalaG)
#B)
Ansiedade3 = statistics.mode(Escala)
print('Á média moda é:',Ansiedade3)
#C)
Ansiedade4 = statistics.median(Escala)
print('Á mediana é:',Ansiedade4)
#D)
Ansiedade5 = statistics.variance(Escala)
print('Á variância é:',Ansiedade5)
#E)
Ansiedade6 = statistics.stdev(Escala)
print('O desvio padrão :',Ansiedade6)'''

#Questão_03
'''KG = [4.0,4.5,5.0,5.0,5.5,6.0,6.0,6.5,6.5,6.5,6.5,7.0,7.0,7.0,7.0,7.0,7.0,7.5,8.5,9.0,9.0,9.0,9.5,10.0,10.0,10.5,11.0,12.0,12.5,13.0,13.0]
CV = (statistics.stdev(KG)/statistics.mean(KG))*100
print('O coeficiente da variação é:',CV)'''

#Questão_04
#A)
'''Delta = [12,15,18,22,17,14,18,23,29,12]
Produção = statistics.mean(Delta)
print('Á média é:',Produção)
#B)
Produção2 = statistics.median(Delta)
print('Á mediana é:',Produção2)
#C)
Produção3 = statistics.stdev(Delta)
print('O desvio padrão é:',Produção3)'''

#Questão_05
'''import statistics

Nota = float
Notas = []
while (Nota != (-999)):
  Nota = float (input('Insira uma para cada aluno! E ao encerrar digite -999'+_+':'))
  if (Nota < 0 or Nota > 10):
    if (Nota == (-999)):
      print('Programa encerrado')
    else:
      print('Nota INVÁLIDA!!,Digite uma nota entre 0 e 10!')
  else:
    Notas.append(Nota)
    print(Notas)
#A)
else:
  Media = statistics.mean(Notas)
print('Á média é:',Media)
#B)
Harmonica = statistics.harmonic_mean(Notas)
print('Á média harmonica é:',Harmonica)
#C)
from scipy.stats.mstats import gmean
Geometrica= gmean(Notas)
print('Á média geometrica é:',Geometrica)
#D)
mod=statistics.mode(Notas)
print('Á média moda é:',mod)
#E)
var = statistics.variance(Notas)
print('Variancia é:',var)
#F)
DP=statistics.stdev(Notas)
print('O desvio padrão é:',DP)
#G)
Cv=statistics.stdev(Notas)/statistics.mean(Notas)*100
print('O coeficiente de variância é:',Cv)'''

#Questão_06
 
'''Nota1 = float(input('Insira a primeira nota:'))
Peso33 = float(input('Á primeira nota deve ter peso3:'))
if (Nota1 <0 or Nota1>10):
     Nota1 = float(input('Nota inválida!!,insira uma nota entre 0 e 10:'))


Nota2 = float(input('Insira segunda nota:'))
peso4 = float(input('Á segunda nota deve ter peso 4:'))
if (Nota2<0 or Nota2>1):
    Nota2 = float(input('Nota inválida!!,insira uma nota entre 0 e 10:'))

Nota3 = float(input('Insira a terceira nota:'))
peso3 =float(input('Á terceira nota deve também ter peso 3:'))
if (Nota3<0 or Nota3>10):
     Nota3 = float(input('Nota inválida!!,insira uma nota entre 0 e 10:'))

Média=(Nota1*Peso33+Nota2*peso4+Nota3*peso3)/(Peso33+peso4+peso3)
print('Á média ponderada é:',Média)'''
